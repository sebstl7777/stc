# %% [markdown]
# # 2D Ising Model — Comparison

# %%
import sys
from pathlib import Path

cwd = Path.cwd()
project_root = cwd if (cwd / "ising_2d").is_dir() else cwd.parent
sys.path.insert(0, str(project_root))

# %%
from ising_2d.funcs import partition_function_2d, free_energy_per_spin, mcmc_ising_baseline, calculate_mcmc_observables, run_stc_ising
